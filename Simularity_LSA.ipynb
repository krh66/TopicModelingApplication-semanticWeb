# %%
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import Normalizer
from sklearn import metrics
from sklearn.cluster import KMeans, MiniBatchKMeans
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords

# %%
n_samples = 2000
n_features = 1000
n_components = 5
n_top_words = 10

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
data = pd.read_csv("./data/dataset.csv", encoding="utf_8")

# %%
stop_words = set(stopwords.words('english'))
stop_words.update(["coffee", "question","questions","answer"])

# %%
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words=stop_words)
tf = tf_vectorizer.fit_transform(data["Body"])

# %%
pd.DataFrame(tf.toarray(), index=data["Body"],columns=tf_vectorizer.get_feature_names())
# Out:
#                                                     10  1000  12  2015  24  \
# Body
# While answering a few of EdChum's questions I d...   0     0   0     0   0
# Being newly created we have zero feeds appearin...   0     0   0     0   0
# It looks like filter coffee has another, differ...   0     0   0     0   0
# The chatroom name is so bland. "Coffee." Look a...   0     0   0     0   0
# On most SE sites, product recommendations are o...   0     0   0     0   0
# ...                                                 ..   ...  ..   ...  ..
# I see no reason why a different rule should app...   0     0   0     0   0
# This tag is used by staff when sharing concepts...   0     0   0     0   0
# Indicates that the post shares product or confi...   0     0   0     0   0
# Seasoned Advice has excluded recipe requests fo...   0     0   0     0   0
# I appreciate the Seasoned Advice stance and thi...   0     0   0     0   0
#
#                                                     51  75  80  ability  able  \
# Body
# While answering a few of EdChum's questions I d...   0   0   0        0     0
# Being newly created we have zero feeds appearin...   0   0   0        0     0
# It looks like filter coffee has another, differ...   0   0   0        0     0
# The chatroom name is so bland. "Coffee." Look a...   0   0   0        0     0
# On most SE sites, product recommendations are o...   0   0   0        0     0
# ...                                                 ..  ..  ..      ...   ...
# I see no reason why a different rule should app...   0   0   0        0     0
# This tag is used by staff when sharing concepts...   0   0   0        0     0
# Indicates that the post shares product or confi...   0   0   0        0     0
# Seasoned Advice has excluded recipe requests fo...   0   0   0        0     0
# I appreciate the Seasoned Advice stance and thi...   0   0   0        0     0
#
#                                                     ...  write  writing  \
# Body                                                ...
# While answering a few of EdChum's questions I d...  ...      0        0
# Being newly created we have zero feeds appearin...  ...      0        0
# It looks like filter coffee has another, differ...  ...      0        0
# The chatroom name is so bland. "Coffee." Look a...  ...      0        0
# On most SE sites, product recommendations are o...  ...      0        0
# ...                                                 ...    ...      ...
# I see no reason why a different rule should app...  ...      0        0
# This tag is used by staff when sharing concepts...  ...      0        0
# Indicates that the post shares product or confi...  ...      0        0
# Seasoned Advice has excluded recipe requests fo...  ...      0        0
# I appreciate the Seasoned Advice stance and thi...  ...      0        0
#
#                                                     wrong  wrote  year  years  \
# Body
# While answering a few of EdChum's questions I d...      0      0     0      0
# Being newly created we have zero feeds appearin...      0      0     0      0
# It looks like filter coffee has another, differ...      0      0     0      0
# The chatroom name is so bland. "Coffee." Look a...      0      1     0      0
# On most SE sites, product recommendations are o...      0      0     0      0
# ...                                                   ...    ...   ...    ...
# I see no reason why a different rule should app...      0      0     0      0
# This tag is used by staff when sharing concepts...      0      0     0      0
# Indicates that the post shares product or confi...      0      0     0      0
# Seasoned Advice has excluded recipe requests fo...      0      0     0      0
# I appreciate the Seasoned Advice stance and thi...      0      0     0      0
#
#                                                     yes  yesterday  yet  zero
# Body
# While answering a few of EdChum's questions I d...    0          0    0     0
# Being newly created we have zero feeds appearin...    0          0    0     1
# It looks like filter coffee has another, differ...    0          0    0     0
# The chatroom name is so bland. "Coffee." Look a...    0          0    0     0
# On most SE sites, product recommendations are o...    0          0    0     0
# ...                                                 ...        ...  ...   ...
# I see no reason why a different rule should app...    0          0    0     0
# This tag is used by staff when sharing concepts...    0          0    0     0
# Indicates that the post shares product or confi...    0          0    0     0
# Seasoned Advice has excluded recipe requests fo...    0          0    0     0
# I appreciate the Seasoned Advice stance and thi...    0          0    0     0
#
# [230 rows x 1000 columns]

# %%
tf_vectorizer.get_feature_names()
# Out:
# ['10',
#  '1000',
#  '12',
#  '2015',
#  '24',
#  '51',
#  '75',
#  '80',
#  'ability',
#  'able',
#  'accept',
#  'acceptable',
#  'accepted',
#  'accepting',
#  'accomplish',
#  'according',
#  'account',
#  'across',
#  'action',
#  'actions',
#  'active',
#  'activity',
#  'actual',
#  'actually',
#  'ad',
#  'add',
#  'added',
#  'adding',
#  'ads',
#  'advertising',
#  'advice',
#  'affect',
#  'ago',
#  'allow',
#  'almost',
#  'along',
#  'already',
#  'also',
#  'alternative',
#  'always',
#  'amount',
#  'another',
#  'answered',
#  'answering',
#  'answers',
#  'anyone',
#  'anything',
#  'anyway',
#  'app',
#  'apparently',
#  'apply',
#  'appreciate',
#  'appreciated',
#  'approach',
#  'appropriate',
#  'approve',
#  'approved',
#  'arabica',
#  'area',
#  'area51',
#  'around',
#  'aside',
#  'ask',
#  'asked',
#  'asker',
#  'asking',
#  'asks',
#  'aspect',
#  'aspects',
#  'associated',
#  'assume',
#  'attempt',
#  'attention',
#  'attract',
#  'attractive',
#  'author',
#  'authoritative',
#  'authors',
#  'auto',
#  'automated',
#  'automatically',
#  'available',
#  'avatar',
#  'avoid',
#  'award',
#  'aware',
#  'away',
#  'awesome',
#  'back',
#  'backed',
#  'background',
#  'bad',
#  'badge',
#  'barista',
#  'base',
#  'based',
#  'bash',
#  'basic',
#  'basically',
#  'basis',
#  'bean',
#  'beans',
#  'become',
#  'becomes',
#  'beginning',
#  'believe',
#  'belong',
#  'benefit',
#  'best',
#  'beta',
#  'better',
#  'beverage',
#  'beverages',
#  'beyond',
#  'big',
#  'biology',
#  'bit',
#  'bitter',
#  'black',
#  'blog',
#  'books',
#  'bounty',
#  'brand',
#  'brands',
#  'break',
#  'breville',
#  'brew',
#  'brewed',
#  'brewing',
#  'broad',
#  'broken',
#  'brown',
#  'building',
#  'button',
#  'buy',
#  'caffeine',
#  'café',
#  'call',
#  'called',
#  'came',
#  'canonical',
#  'case',
#  'cases',
#  'center',
#  'certain',
#  'certainly',
#  'challenges',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'chat',
#  'chatroom',
#  'check',
#  'checked',
#  'chemistry',
#  'circumstances',
#  'clarification',
#  'clear',
#  'clearly',
#  'click',
#  'close',
#  'closed',
#  'code',
#  'coffeemaker',
#  'coffees',
#  'cold',
#  'color',
#  'com',
#  'come',
#  'comes',
#  'coming',
#  'comment',
#  'comments',
#  'common',
#  'communities',
#  'community',
#  'company',
#  'completely',
#  'components',
#  'concept',
#  'confused',
#  'consider',
#  'considered',
#  'consuming',
#  'contain',
#  'contains',
#  'content',
#  'context',
#  'continue',
#  'contribute',
#  'contributed',
#  'contributes',
#  'contributions',
#  'convention',
#  'cooking',
#  'correct',
#  'cost',
#  'could',
#  'count',
#  'couple',
#  'course',
#  'covered',
#  'create',
#  'created',
#  'creating',
#  'criteria',
#  'critical',
#  'cup',
#  'cups',
#  'current',
#  'currently',
#  'cw',
#  'daily',
#  'dark',
#  'data',
#  'day',
#  'days',
#  'deal',
#  'decide',
#  'decided',
#  'dedicated',
#  'define',
#  'defined',
#  'definitely',
#  'deleted',
#  'demonstrates',
#  'descaler',
#  'descaling',
#  'describe',
#  'designed',
#  'despite',
#  'destroyed',
#  'detailed',
#  'details',
#  'determine',
#  'difference',
#  'differences',
#  'different',
#  'direction',
#  'directly',
#  'disagree',
#  'disclaimer',
#  'discourage',
#  'discovery',
#  'discuss',
#  'discussion',
#  'discussions',
#  'distinguishing',
#  'done',
#  'double',
#  'downvote',
#  'dr',
#  'draw',
#  'drink',
#  'drinkers',
#  'drinking',
#  'drinks',
#  'drip',
#  'drop',
#  'dropdown',
#  'due',
#  'duplicate',
#  'duplicates',
#  'early',
#  'earn',
#  'earned',
#  'earning',
#  'easier',
#  'easily',
#  'easy',
#  'edit',
#  'edited',
#  'editing',
#  'edits',
#  'effect',
#  'effects',
#  'effort',
#  'eg',
#  'either',
#  'electricity',
#  'else',
#  'elsewhere',
#  'en',
#  'encourage',
#  'end',
#  'ended',
#  'ending',
#  'engine',
#  'enjoy',
#  'enough',
#  'equipment',
#  'especially',
#  'espresso',
#  'essentially',
#  'etc',
#  'even',
#  'event',
#  'every',
#  'everyone',
#  'everything',
#  'exact',
#  'exactly',
#  'example',
#  'examples',
#  'excellent',
#  'except',
#  'exchange',
#  'existing',
#  'expand',
#  'expect',
#  'experience',
#  'experiences',
#  'experiment',
#  'expert',
#  'expertise',
#  'experts',
#  'explanations',
#  'extent',
#  'fact',
#  'factors',
#  'facts',
#  'failure',
#  'fair',
#  'fairly',
#  'far',
#  'favor',
#  'feature',
#  'features',
#  'feed',
#  'feedback',
#  'feel',
#  'fewer',
#  'field',
#  'figure',
#  'filter',
#  'final',
#  'finally',
#  'find',
#  'finding',
#  'fine',
#  'first',
#  'fit',
#  'fits',
#  'flag',
#  'flagged',
#  'flags',
#  'flavor',
#  'flavored',
#  'flavoring',
#  'flavors',
#  'flavour',
#  'focus',
#  'folks',
#  'follow',
#  'following',
#  'follows',
#  'food',
#  'forever',
#  'form',
#  'format',
#  'found',
#  'frame',
#  'french',
#  'full',
#  'fully',
#  'fun',
#  'fundamental',
#  'funny',
#  'future',
#  'gaggia',
#  'game',
#  'gave',
#  'gear',
#  'general',
#  'generally',
#  'get',
#  'gets',
#  'getting',
#  'give',
#  'given',
#  'gives',
#  'giving',
#  'glass',
#  'go',
#  'goal',
#  'goes',
#  'going',
#  'good',
#  'google',
#  'got',
#  'great',
#  'grind',
#  'grinder',
#  'grinding',
#  'grinds',
#  'ground',
#  'grounds',
#  'growing',
#  'grown',
#  'guidance',
#  'guidelines',
#  'guys',
#  'half',
#  'hand',
#  'handle',
#  'handled',
#  'happen',
#  'happened',
#  'happens',
#  'happy',
#  'hard',
#  'hat',
#  'hats',
#  'health',
#  'healthy',
#  'help',
#  'helpful',
#  'helps',
#  'high',
#  'higher',
#  'highest',
#  'highly',
#  'history',
#  'hits',
#  'hoc_age',
#  'hold',
#  'home',
#  'honest',
#  'hope',
#  'hopefully',
#  'hot',
#  'hours',
#  'however',
#  'http',
#  'https',
#  'huge',
#  'iced',
#  'icons',
#  'idea',
#  'ideas',
#  'identify',
#  'image',
#  'immediately',
#  'imo',
#  'important',
#  'improve',
#  'include',
#  'includes',
#  'including',
#  'indeed',
#  'indicate',
#  'individual',
#  'information',
#  'ingredient',
#  'ingredients',
#  'initial',
#  'instead',
#  'intended',
#  'interest',
#  'interested',
#  'interesting',
#  'interface',
#  'internet',
#  'introduce',
#  'issue',
#  'issues',
#  'japan',
#  'job',
#  'keep',
#  'key',
#  'kind',
#  'kinds',
#  'know',
#  'knowledge',
#  'known',
#  'kopi',
#  'large',
#  'last',
#  'late',
#  'lead',
#  'learn',
#  'learned',
#  'learning',
#  'least',
#  'leave',
#  'left',
#  'legitimate',
#  'length',
#  'less',
#  'let',
#  'level',
#  'light',
#  'like',
#  'likely',
#  'limit',
#  'line',
#  'link',
#  'linked',
#  'links',
#  'list',
#  'lists',
#  'little',
#  'logo',
#  'london',
#  'long',
#  'look',
#  'looking',
#  'looks',
#  'lot',
#  'lots',
#  'love',
#  'low',
#  'luwak',
#  'machine',
#  'machines',
#  'made',
#  'main',
#  'maintain',
#  'major',
#  'make',
#  'makes',
#  'making',
#  'manage',
#  'manageable',
#  'manner',
#  'manual',
#  'manually',
#  'manufacturer',
#  'many',
#  'mark',
#  'math',
#  'matter',
#  'may',
#  'maybe',
#  'mean',
#  'meaning',
#  'meaningful',
#  'means',
#  'member',
#  'members',
#  'membership',
#  'mention',
#  'menu',
#  'merged',
#  'message',
#  'meta',
#  'method',
#  'methods',
#  'middle',
#  'might',
#  'migrate',
#  'migrated',
#  'migration',
#  'mind',
#  'mine',
#  'minimum',
#  'minor',
#  'minutes',
#  'misleading',
#  'missing',
#  'mix',
#  'mod',
#  'moderation',
#  'moderator',
#  'moderators',
#  'mods',
#  'moka',
#  'moment',
#  'money',
#  'months',
#  'mostly',
#  'moving',
#  'much',
#  'multiple',
#  'must',
#  'name',
#  'names',
#  'nature',
#  'nearly',
#  'neatly',
#  'necessarily',
#  'necessary',
#  'need',
#  'needed',
#  'needs',
#  'network',
#  'never',
#  'new',
#  'next',
#  'non',
#  'note',
#  'nothing',
#  'number',
#  'numbers',
#  'numerous',
#  'obvious',
#  'obviously',
#  'official',
#  'often',
#  'oil',
#  'okay',
#  'old',
#  'one',
#  'ones',
#  'op',
#  'open',
#  'opinion',
#  'opinions',
#  'opt',
#  'order',
#  'original',
#  'others',
#  'otherwise',
#  'overall',
#  'overflow',
#  'page',
#  'pages',
#  'part',
#  'participating',
#  'participation',
#  'particular',
#  'past',
#  'pause',
#  'people',
#  'per',
#  'percolator',
#  'perfectly',
#  'perhaps',
#  'period',
#  'person',
#  'personal',
#  'personally',
#  'place',
#  'places',
#  'plain',
#  'please',
#  'png',
#  'point',
#  'points',
#  'policy',
#  'polls',
#  'poor',
#  'pop',
#  'popular',
#  'position',
#  'possible',
#  'possibly',
#  'post',
#  'posted',
#  'posting',
#  'posts',
#  'potential',
#  'potentially',
#  'pour',
#  'prefer',
#  'preparation',
#  'press',
#  'pretty',
#  'previous',
#  'previously',
#  'primarily',
#  'primary',
#  'prior',
#  'private',
#  'privileges',
#  'probably',
#  'problem',
#  'problematic',
#  'problems',
#  'process',
#  'processed',
#  'producing',
#  'product',
#  'products',
#  'professionals',
#  'project',
#  'promotion',
#  'proper',
#  'properly',
#  'proposal',
#  'proposals',
#  'proposed',
#  'provide',
#  'provided',
#  'providing',
#  'public',
#  'pure',
#  'push',
#  'put',
#  'putting',
#  'quality',
#  'queue',
#  'quickly',
#  'quite',
#  'rather',
#  'read',
#  'reading',
#  'real',
#  'really',
#  'reason',
#  'reasonable',
#  'reasons',
#  'received',
#  'recent',
#  'recently',
#  'recipe',
#  'recipes',
#  'recommendation',
#  'recommendations',
#  'recommended',
#  'recreated',
#  'red',
#  'redundant',
#  'refer',
#  'reference',
#  'references',
#  'refers',
#  'regarding',
#  'regional',
#  'regular',
#  'related',
#  'relating',
#  'relevant',
#  'remain',
#  'removed',
#  'reopen',
#  'rep',
#  'reputation',
#  'requests',
#  'require',
#  'requirements',
#  'research',
#  'resource',
#  'response',
#  'rest',
#  'result',
#  'review',
#  'reviewing',
#  'reviews',
#  'right',
#  'roast',
#  'roasting',
#  'roasts',
#  'room',
#  'rooms',
#  'rule',
#  'rules',
#  'run',
#  'sa',
#  'sage',
#  'said',
#  'sam',
#  'satisfied',
#  'say',
#  'says',
#  'science',
#  'scientific',
#  'scope',
#  'se',
#  'search',
#  'searched',
#  'searching',
#  'seasoned',
#  'second',
#  'secret',
#  'section',
#  'see',
#  'seem',
#  'seems',
#  'seen',
#  'select',
#  'self',
#  'sense',
#  'separate',
#  'serious',
#  'seriously',
#  'serving',
#  'set',
#  'several',
#  'shape',
#  'share',
#  'shop',
#  'short',
#  'show',
#  'shown',
#  'side',
#  'signatures',
#  'significant',
#  'similar',
#  'simple',
#  'simply',
#  'since',
#  'site',
#  'sites',
#  'situation',
#  'size',
#  'skip',
#  'slightly',
#  'software',
#  'solve',
#  'solved',
#  'someone',
#  'something',
#  'sometimes',
#  'somewhat',
#  'soon',
#  'sort',
#  'sorts',
#  'sounds',
#  'source',
#  'sources',
#  'space',
#  'spam',
#  'special',
#  'species',
#  'specific',
#  'specifically',
#  'spent',
#  'spirit',
#  'split',
#  'stack',
#  'stackexchange',
#  'stackoverflow',
#  'standard',
#  'start',
#  'started',
#  'starting',
#  'starts',
#  'state',
#  'stats',
#  'stay',
#  'steam',
#  'still',
#  'stop',
#  'storage',
#  'stovetop',
#  'structured',
#  'stuff',
#  'sub',
#  'subject',
#  'subjective',
#  'submit',
#  'submitted',
#  'success',
#  'sufficient',
#  'suggest',
#  'suggested',
#  'suggestion',
#  'suggestions',
#  'summary',
#  'superfluous',
#  'support',
#  'suppose',
#  'sure',
#  'survive',
#  'suspect',
#  'suspend',
#  'suspended',
#  'sweet',
#  'synonym',
#  'synonyms',
#  'system',
#  'tag',
#  'tags',
#  'take',
#  'takes',
#  'taking',
#  'talking',
#  'tasks',
#  'taste',
#  'tastes',
#  'tea',
#  'technique',
#  'tell',
#  'temperature',
#  'tend',
#  'tendency',
#  'term',
#  'terminology',
#  'terms',
#  'text',
#  'thank',
#  'thanks',
#  'themes',
#  'theory',
#  'therefore',
#  'therewillbecoffee',
#  'thing',
#  'things',
#  'think',
#  'thinking',
#  'thinks',
#  'third',
#  'thoroughly',
#  'though',
#  'thought',
#  'thoughtful',
#  'thoughts',
#  'thousands',
#  'thread',
#  'three',
#  'threshold',
#  'throw',
#  'throwing',
#  'thus',
#  'time',
#  'times',
#  'tiny',
#  'tl',
#  'today',
#  'together',
#  'top',
#  'topic',
#  'topics',
#  'totally',
#  'tour',
#  'traditional',
#  'traffic',
#  'trends',
#  'tried',
#  'true',
#  'try',
#  'trying',
#  'turn',
#  'two',
#  'type',
#  'types',
#  'uk',
#  'unaccepted',
#  'understand',
#  'understanding',
#  'unique',
#  'unless',
#  'update',
#  'upvote',
#  'us',
#  'use',
#  'used',
#  'useful',
#  'user',
#  'users',
#  'uses',
#  'using',
#  'usually',
#  'valid',
#  'value',
#  'variations',
#  'variety',
#  'various',
#  'verifiable',
#  'via',
#  'view',
#  'viewed',
#  'virtual',
#  'visit',
#  'vote',
#  'voted',
#  'votes',
#  'voting',
#  'want',
#  'wanted',
#  'warm',
#  'water',
#  'way',
#  'ways',
#  'website',
#  'week',
#  'welcome',
#  'welcoming',
#  'well',
#  'whether',
#  'whole',
#  'whose',
#  'wide',
#  'wiki',
#  'wikipedia',
#  'wikis',
#  'winter',
#  'wish',
#  'within',
#  'without',
#  'wonder',
#  'word',
#  'work',
#  'working',
#  'works',
#  'world',
#  'would',
#  'write',
#  'writing',
#  'wrong',
#  'wrote',
#  'year',
#  'years',
#  'yes',
#  'yesterday',
#  'yet',
#  'zero']

# %%
lsa = TruncatedSVD(n_components=n_components, n_iter=100, random_state=42)
tfidf_lsa = lsa.fit_transform(tf)

# %%
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lsa, tf_feature_names, n_top_words)
# Out:
# Topic #0: site answers like think one would topic sites meta people
# Topic #1: tag wiki flavor edit content one process brewing like history
# Topic #2: queue tag tasks flags users moderation wiki posts edit user
# Topic #3: hats bash winter public earn site viewed se particular well
# Topic #4: meta sites edit people main suggested want participation work site
